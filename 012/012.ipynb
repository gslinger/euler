# %% [markdown]
# ## Problem 12: Highly divisible triangular number
#
# The sequence of triangle numbers is generated by adding the natural numbers. So the 7<sup>th</sup> triangle number would be 1 + 2 + 3 + 4 + 5 + 6 + 7 = 28\. The first ten terms would be:
#
# 1, 3, 6, 10, 15, 21, 28, 36, 45, 55, ...
#
# Let us list the factors of the first seven triangle numbers:
#
# > **1**: 1
# > **3**: 1,3
# > **6**: 1,2,3,6
# > **10**: 1,2,5,10
# > **15**: 1,3,5,15
# > **21**: 1,3,7,21
# > **28**: 1,2,4,7,14,28
#
# We can see that 28 is the first triangle number to have over five divisors.
#
# What is the value of the first triangle number to have over five hundred divisors?

# %%
# Source : https://blog.dreamshire.com/solutions/project_euler/project-euler-problem-012-solution/

# TODO Need to spend some more time understanding this one.. 

def first_tri_number_with_n_divisors(n: int) -> int:
    max: int = 100000
    d: list = [0] * max
    for i in range(1, max):
        for j in range(i, max, i):
            d[j] += 1
        div_count = d[i - 1] * d[i // 2] if i % 2 == 0 else d[(i - 1) // 2] * d[i]
        if div_count > n:
            return (i - 1) * i // 2

# %timeit -r5 -n3 first_tri_number_with_n_divisors(500)
first_tri_number_with_n_divisors(500)
# Out:
# 88.4 ms ± 1.03 ms per loop (mean ± std. dev. of 5 runs, 3 loops each)
# 76576500
